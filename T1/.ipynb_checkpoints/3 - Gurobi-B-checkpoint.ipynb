# %% [markdown]
# ## Gurobi - Instâncias B (números reais)

# %%
using JuMP
using DelimitedFiles
using Gurobi
using MathOptInterface
using CSV
using DataFrames

const MOI = MathOptInterface

# Criando os arrays que irão armazenar os dados de resolução de cada instância
fileName = []
agentsNumber = []
solveTime = []
isOptimalSolution = []
solution = []

const GRB_ENV = Gurobi.Env()

# Criando uma instância do solver Gurobi
solver = () -> Gurobi.Optimizer(GRB_ENV)

# Obtendo o nome de todas as instâncias
files = readdir("instancias/instb"; join=true)
# Out:
# Academic license - for non-commercial use only - expires 2021-11-25
# 100-element Vector{String}:
#  "instancias/instb/instb_2_10_100.txt"
#  "instancias/instb/instb_2_10_1000.txt"
#  "instancias/instb/instb_2_10_200.txt"
#  "instancias/instb/instb_2_10_50.txt"
#  "instancias/instb/instb_2_10_500.txt"
#  "instancias/instb/instb_2_1_100.txt"
#  "instancias/instb/instb_2_1_1000.txt"
#  "instancias/instb/instb_2_1_200.txt"
#  "instancias/instb/instb_2_1_50.txt"
#  "instancias/instb/instb_2_1_500.txt"
#  "instancias/instb/instb_2_2_100.txt"
#  "instancias/instb/instb_2_2_1000.txt"
#  "instancias/instb/instb_2_2_200.txt"
#  ⋮
#  "instancias/instb/instb_3_7_50.txt"
#  "instancias/instb/instb_3_7_500.txt"
#  "instancias/instb/instb_3_8_100.txt"
#  "instancias/instb/instb_3_8_1000.txt"
#  "instancias/instb/instb_3_8_200.txt"
#  "instancias/instb/instb_3_8_50.txt"
#  "instancias/instb/instb_3_8_500.txt"
#  "instancias/instb/instb_3_9_100.txt"
#  "instancias/instb/instb_3_9_1000.txt"
#  "instancias/instb/instb_3_9_200.txt"
#  "instancias/instb/instb_3_9_50.txt"
#  "instancias/instb/instb_3_9_500.txt"

# %%
# Iterando sob cada instância
for f in files

    # Criando o modelo que usa o Gurobi solver
    model = Model(solver)
    set_optimizer_attribute(model, "TimeLimit", 30)
    set_optimizer_attribute(model, "Heuristics", 0.0)
    set_optimizer_attribute(model, "OutputFlag", 0)

    # Lendo a matriz de custo
    c = readdlm(f, Float64)

    # Checando o tamanho das linhas da matriz
    n = size(c)[1]

    # Definindo variável de decisão -> Xij = {0,1}
    @variable(model,x[i=1:n,j=1:n], Bin)

    # Função objetivo
    @objective(model, Max, sum(c[i, j] * x[i, j] for i in 1:n, j in 1:n))

    # Restrições para garantir a saída de todo vértice
    for i in 1:n
        @constraint(model,sum(x[i,j] for j in 1 : n) == 1)
    end

    # Restrições para garantir a chegada em cada vértice
    for j in 1:n
        @constraint(model,sum(x[i,j] for i in 1:n) == 1)
    end

    # Trazendo uma solução otima
    JuMP.optimize!(model)

    # Adicionando nos arrays os valores referentes a instância em questão e sua solução.
    push!(fileName, f)
    push!(agentsNumber, n)
    push!(solveTime, solve_time(model))
    push!(isOptimalSolution, termination_status(model) == MOI.OPTIMAL)
    push!(solution, objective_value(model))
end

# %%
# Criando um dataframe com os dados coletados
const dataFrame = DataFrame(
    file_name = fileName,
    agents_number = agentsNumber,
    solve_time = solveTime,
    is_optimal_solution = isOptimalSolution,
    solution = solution
)

# Escrevendo esse dataframe em um .csv para uma futura análise dos dados
CSV.write("gurobi_data_instb.csv", dataFrame)

println(dataFrame)
# Out:
# 100×5 DataFrame
#  Row │ file_name                          agents_number  solve_time  is_optimal_solution  solution
#      │ Any                                Any            Any         Any                  Any
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────────
#    1 │ instancias/instb/instb_2_10_100.…  100            0.0429928   true                 4935.02
#    2 │ instancias/instb/instb_2_10_1000…  1000           13.5589     true                 49926.4
#    3 │ instancias/instb/instb_2_10_200.…  200            0.119022    true                 9924.66
#    4 │ instancias/instb/instb_2_10_50.t…  50             0.0108931   true                 2421.15
#    5 │ instancias/instb/instb_2_10_500.…  500            3.0891      true                 24921.1
#    6 │ instancias/instb/instb_2_1_100.t…  100            0.029247    true                 4927.71
#    7 │ instancias/instb/instb_2_1_1000.…  1000           13.2337     true                 49926.2
#    8 │ instancias/instb/instb_2_1_200.t…  200            0.129186    true                 9931.69
#    9 │ instancias/instb/instb_2_1_50.txt  50             0.011024    true                 2423.4
#   10 │ instancias/instb/instb_2_1_500.t…  500            2.85412     true                 24925.6
#   11 │ instancias/instb/instb_2_2_100.t…  100            0.029916    true                 4929.36
#   12 │ instancias/instb/instb_2_2_1000.…  1000           14.5353     true                 49925.7
#   13 │ instancias/instb/instb_2_2_200.t…  200            0.129106    true                 9927.93
#   14 │ instancias/instb/instb_2_2_50.txt  50             0.0120299   true                 2424.89
#   15 │ instancias/instb/instb_2_2_500.t…  500            3.13466     true                 24923.3
#   16 │ instancias/instb/instb_2_3_100.t…  100            0.029886    true                 4929.15
#   17 │ instancias/instb/instb_2_3_1000.…  1000           13.3582     true                 49925.7
#   18 │ instancias/instb/instb_2_3_200.t…  200            0.124662    true                 9925.82
#   19 │ instancias/instb/instb_2_3_50.txt  50             0.0108662   true                 2431.3
#   20 │ instancias/instb/instb_2_3_500.t…  500            2.95452     true                 24921.6
#   21 │ instancias/instb/instb_2_4_100.t…  100            0.0564148   true                 4936.53
#   22 │ instancias/instb/instb_2_4_1000.…  1000           13.2135     true                 49926.4
#   23 │ instancias/instb/instb_2_4_200.t…  200            0.168741    true                 9922.47
#   24 │ instancias/instb/instb_2_4_50.txt  50             0.017714    true                 2436.74
#   25 │ instancias/instb/instb_2_4_500.t…  500            2.82781     true                 24926.2
#   26 │ instancias/instb/instb_2_5_100.t…  100            0.0380349   true                 4934.44
#   27 │ instancias/instb/instb_2_5_1000.…  1000           14.6315     true                 49925.8
#   28 │ instancias/instb/instb_2_5_200.t…  200            0.111525    true                 9921.49
#   29 │ instancias/instb/instb_2_5_50.txt  50             0.0114419   true                 2434.47
#   66 │ instancias/instb/instb_3_3_100.t…  100            0.0264161   true                 49197.4
#   67 │ instancias/instb/instb_3_3_1000.…  1000           13.4756     true                 4.99173e5
#   68 │ instancias/instb/instb_3_3_200.t…  200            0.135699    true                 99224.4
#   69 │ instancias/instb/instb_3_3_50.txt  50             0.011893    true                 24097.9
#   70 │ instancias/instb/instb_3_3_500.t…  500            2.86047     true                 2.49173e5
#   71 │ instancias/instb/instb_3_4_100.t…  100            0.0273581   true                 49267.6
#   72 │ instancias/instb/instb_3_4_1000.…  1000           13.1002     true                 4.99167e5
#   73 │ instancias/instb/instb_3_4_200.t…  200            0.136928    true                 99181.4
#   74 │ instancias/instb/instb_3_4_50.txt  50             0.010119    true                 24321.0
#   75 │ instancias/instb/instb_3_4_500.t…  500            2.86046     true                 2.49166e5
#   76 │ instancias/instb/instb_3_5_100.t…  100            0.0311382   true                 49144.1
#   77 │ instancias/instb/instb_3_5_1000.…  1000           13.3561     true                 4.99194e5
#   78 │ instancias/instb/instb_3_5_200.t…  200            0.119916    true                 99119.7
#   79 │ instancias/instb/instb_3_5_50.txt  50             0.021419    true                 24264.1
#   80 │ instancias/instb/instb_3_5_500.t…  500            2.63084     true                 2.49247e5
#   81 │ instancias/instb/instb_3_6_100.t…  100            0.0264978   true                 48990.1
#   82 │ instancias/instb/instb_3_6_1000.…  1000           12.4909     true                 4.99169e5
#   83 │ instancias/instb/instb_3_6_200.t…  200            0.11816     true                 99213.5
#   84 │ instancias/instb/instb_3_6_50.txt  50             0.0164411   true                 24201.7
#   85 │ instancias/instb/instb_3_6_500.t…  500            2.54053     true                 2.49205e5
#   86 │ instancias/instb/instb_3_7_100.t…  100            0.027478    true                 49241.2
#   87 │ instancias/instb/instb_3_7_1000.…  1000           12.619      true                 4.99159e5
#   88 │ instancias/instb/instb_3_7_200.t…  200            0.099237    true                 99218.5
#   89 │ instancias/instb/instb_3_7_50.txt  50             0.00981593  true                 24249.7
#   90 │ instancias/instb/instb_3_7_500.t…  500            2.58022     true                 249160.0
#   91 │ instancias/instb/instb_3_8_100.t…  100            0.0258248   true                 49292.6
#   92 │ instancias/instb/instb_3_8_1000.…  1000           12.5327     true                 4.99217e5
#   93 │ instancias/instb/instb_3_8_200.t…  200            0.11565     true                 99223.4
#   94 │ instancias/instb/instb_3_8_50.txt  50             0.010344    true                 24184.7
#   95 │ instancias/instb/instb_3_8_500.t…  500            2.47142     true                 2.49158e5
#   96 │ instancias/instb/instb_3_9_100.t…  100            0.0290139   true                 49261.7
#   97 │ instancias/instb/instb_3_9_1000.…  1000           12.0946     true                 4.99208e5
#   98 │ instancias/instb/instb_3_9_200.t…  200            0.104589    true                 99210.8
#   99 │ instancias/instb/instb_3_9_50.txt  50             0.0105879   true                 24118.7
#  100 │ instancias/instb/instb_3_9_500.t…  500            2.48511     true                 249194.0

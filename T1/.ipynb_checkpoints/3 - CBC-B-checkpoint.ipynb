# %% [markdown]
# ## CBC - Instâncias B (números reais)

# %%
using JuMP
using DelimitedFiles
using Cbc
using MathOptInterface
using CSV
using DataFrames

const MOI = MathOptInterface

# Criando os arrays que irão armazenar os dados de resolução de cada instância
fileName = []
agentsNumber = []
solveTime = []
isOptimalSolution = []
solution = []

# Obtendo o nome de todas as instâncias
files = readdir("instancias/instb"; join=true)
# Out:
# 100-element Vector{String}:
#  "instancias/instb/instb_2_10_100.txt"
#  "instancias/instb/instb_2_10_1000.txt"
#  "instancias/instb/instb_2_10_200.txt"
#  "instancias/instb/instb_2_10_50.txt"
#  "instancias/instb/instb_2_10_500.txt"
#  "instancias/instb/instb_2_1_100.txt"
#  "instancias/instb/instb_2_1_1000.txt"
#  "instancias/instb/instb_2_1_200.txt"
#  "instancias/instb/instb_2_1_50.txt"
#  "instancias/instb/instb_2_1_500.txt"
#  "instancias/instb/instb_2_2_100.txt"
#  "instancias/instb/instb_2_2_1000.txt"
#  "instancias/instb/instb_2_2_200.txt"
#  ⋮
#  "instancias/instb/instb_3_7_50.txt"
#  "instancias/instb/instb_3_7_500.txt"
#  "instancias/instb/instb_3_8_100.txt"
#  "instancias/instb/instb_3_8_1000.txt"
#  "instancias/instb/instb_3_8_200.txt"
#  "instancias/instb/instb_3_8_50.txt"
#  "instancias/instb/instb_3_8_500.txt"
#  "instancias/instb/instb_3_9_100.txt"
#  "instancias/instb/instb_3_9_1000.txt"
#  "instancias/instb/instb_3_9_200.txt"
#  "instancias/instb/instb_3_9_50.txt"
#  "instancias/instb/instb_3_9_500.txt"

# %%
# Iterando sob cada instância
for f in files

    # Criando o modelo que usa o CBC solver
    model = Model(Cbc.Optimizer)
    set_optimizer_attribute(model, "seconds", 60 * 30)
    set_optimizer_attribute(model, "Heuristics", "off")
    set_optimizer_attribute(model, "logLevel", 0)

    # Lendo a matriz de custo
    c = readdlm(f, Float64)

    # Checando o tamanho das linhas da matriz
    n = size(c)[1]

    # Definindo variável de decisão -> Xij = {0,1}
    @variable(model,x[i=1:n,j=1:n], Bin)

    # Função objetivo
    @objective(model, Max, sum(c[i, j] * x[i, j] for i in 1:n, j in 1:n))

    # Restrições para garantir a saída de todo vértice
    for i in 1:n
        @constraint(model,sum(x[i,j] for j in 1 : n) == 1)
    end

    # Restrições para garantir a chegada em cada vértice
    for j in 1:n
        @constraint(model,sum(x[i,j] for i in 1:n) == 1)
    end

    # Trazendo uma solução otima
    JuMP.optimize!(model)

    # Adicionando nos arrays os valores referentes a instância em questão e sua solução.
    push!(fileName, f)
    push!(agentsNumber, n)
    push!(solveTime, solve_time(model))
    push!(isOptimalSolution, termination_status(model) == MOI.OPTIMAL)
    push!(solution, objective_value(model))
end
# Out:
# 51 slacks added
# row inf 1.66533e-15
# column inf 6.16989e-10
# row inf 1.58762e-14
# column inf 8.1171e-08
# row inf 1.89848e-14
# column inf 1.44575e-07
# row inf 0
# column inf 0
# row inf 0
# column inf 0
# row inf 1.64313e-14
# column inf 2.35069e-08
# row inf 1.34337e-14
# column inf 4.23358e-08
# row inf 0
# column inf 0
# row inf 0
# column inf 0
# row inf 3.10862e-15
# column inf 2.34699e-09
# row inf 1.02141e-14
# column inf 3.6314e-08
# row inf 1.28786e-14
# column inf 1.98309e-08
# row inf 0
# column inf 1.61996e-10

# %%
# Criando um dataframe com os dados coletados
const dataFrame = DataFrame(
    file_name = fileName,
    agents_number = agentsNumber,
    solve_time = solveTime,
    is_optimal_solution = isOptimalSolution,
    solution = solution
)

# Escrevendo esse dataframe em um .csv para uma futura análise dos dados
CSV.write("cbc_data_instb.csv", dataFrame)

println(dataFrame)
# Out:
# 100×5 DataFrame
#  Row │ file_name                          agents_number  solve_time  is_optimal_solution  solution
#      │ Any                                Any            Any         Any                  Any
# ─────┼──────────────────────────────────────────────────────────────────────────────────────────────
#    1 │ instancias/instb/instb_2_10_100.…  100            0.224349    true                 4935.02
#    2 │ instancias/instb/instb_2_10_1000…  1000           56.589      true                 49926.4
#    3 │ instancias/instb/instb_2_10_200.…  200            0.611783    true                 9924.66
#    4 │ instancias/instb/instb_2_10_50.t…  50             0.0413752   true                 2421.15
#    5 │ instancias/instb/instb_2_10_500.…  500            7.87535     true                 24921.1
#    6 │ instancias/instb/instb_2_1_100.t…  100            0.180668    true                 4927.71
#    7 │ instancias/instb/instb_2_1_1000.…  1000           66.498      true                 49926.2
#    8 │ instancias/instb/instb_2_1_200.t…  200            0.60237     true                 9931.69
#    9 │ instancias/instb/instb_2_1_50.txt  50             0.0362401   true                 2423.4
#   10 │ instancias/instb/instb_2_1_500.t…  500            8.21584     true                 24925.6
#   11 │ instancias/instb/instb_2_2_100.t…  100            0.211595    true                 4929.36
#   12 │ instancias/instb/instb_2_2_1000.…  1000           80.8254     true                 49925.7
#   13 │ instancias/instb/instb_2_2_200.t…  200            0.60192     true                 9927.93
#   14 │ instancias/instb/instb_2_2_50.txt  50             0.0314491   true                 2424.89
#   15 │ instancias/instb/instb_2_2_500.t…  500            7.59909     true                 24923.3
#   16 │ instancias/instb/instb_2_3_100.t…  100            0.182689    true                 4929.15
#   17 │ instancias/instb/instb_2_3_1000.…  1000           53.9946     true                 49925.7
#   18 │ instancias/instb/instb_2_3_200.t…  200            0.590996    true                 9925.82
#   19 │ instancias/instb/instb_2_3_50.txt  50             0.0319982   true                 2431.3
#   20 │ instancias/instb/instb_2_3_500.t…  500            7.45283     true                 24921.6
#   21 │ instancias/instb/instb_2_4_100.t…  100            0.17727     true                 4936.53
#   22 │ instancias/instb/instb_2_4_1000.…  1000           58.707      true                 49926.4
#   23 │ instancias/instb/instb_2_4_200.t…  200            0.691643    true                 9922.47
#   24 │ instancias/instb/instb_2_4_50.txt  50             0.0412331   true                 2436.74
#   25 │ instancias/instb/instb_2_4_500.t…  500            7.47917     true                 24926.2
#   26 │ instancias/instb/instb_2_5_100.t…  100            0.174935    true                 4934.44
#   27 │ instancias/instb/instb_2_5_1000.…  1000           60.2077     true                 49925.8
#   28 │ instancias/instb/instb_2_5_200.t…  200            0.617956    true                 9921.49
#   29 │ instancias/instb/instb_2_5_50.txt  50             0.0392978   true                 2434.47
#   30 │ instancias/instb/instb_2_5_500.t…  500            7.58156     true                 24922.9
#   31 │ instancias/instb/instb_2_6_100.t…  100            0.211874    true                 4933.6
#   32 │ instancias/instb/instb_2_6_1000.…  1000           50.9736     true                 49924.7
#   33 │ instancias/instb/instb_2_6_200.t…  200            0.568139    true                 9931.97
#   34 │ instancias/instb/instb_2_6_50.txt  50             0.03109     true                 2433.43
#   35 │ instancias/instb/instb_2_6_500.t…  500            7.4184      true                 24925.3
#   36 │ instancias/instb/instb_2_7_100.t…  100            0.180701    true                 4924.02
#   37 │ instancias/instb/instb_2_7_1000.…  1000           49.0228     true                 49926.6
#   38 │ instancias/instb/instb_2_7_200.t…  200            0.54843     true                 9928.08
#   39 │ instancias/instb/instb_2_7_50.txt  50             0.030313    true                 2424.54
#   40 │ instancias/instb/instb_2_7_500.t…  500            6.87268     true                 24925.8
#   41 │ instancias/instb/instb_2_8_100.t…  100            0.15847     true                 4922.67
#   42 │ instancias/instb/instb_2_8_1000.…  1000           49.5032     true                 49924.4
#   43 │ instancias/instb/instb_2_8_200.t…  200            0.569117    true                 9925.28
#   44 │ instancias/instb/instb_2_8_50.txt  50             0.030745    true                 2420.88
#   45 │ instancias/instb/instb_2_8_500.t…  500            7.91327     true                 24926.2
#   46 │ instancias/instb/instb_2_9_100.t…  100            0.160306    true                 4923.37
#   47 │ instancias/instb/instb_2_9_1000.…  1000           55.1011     true                 49923.9
#   48 │ instancias/instb/instb_2_9_200.t…  200            0.556534    true                 9924.34
#   49 │ instancias/instb/instb_2_9_50.txt  50             0.0309379   true                 2439.88
#   50 │ instancias/instb/instb_2_9_500.t…  500            7.03775     true                 24924.8
#   51 │ instancias/instb/instb_3_10_100.…  100            0.141298    true                 49214.9
#   52 │ instancias/instb/instb_3_10_1000…  1000           50.1821     true                 4.99192e5
#   53 │ instancias/instb/instb_3_10_200.…  200            0.596302    true                 99175.2
#   54 │ instancias/instb/instb_3_10_50.t…  50             0.0309949   true                 24369.9
#   55 │ instancias/instb/instb_3_10_500.…  500            7.00402     true                 2.49195e5
#   56 │ instancias/instb/instb_3_1_100.t…  100            0.142811    true                 49204.3
#   57 │ instancias/instb/instb_3_1_1000.…  1000           51.122      true                 4.99192e5
#   58 │ instancias/instb/instb_3_1_200.t…  200            0.596177    true                 99230.6
#   59 │ instancias/instb/instb_3_1_50.txt  50             0.0331461   true                 24200.0
#   60 │ instancias/instb/instb_3_1_500.t…  500            7.01943     true                 2.49171e5
#   61 │ instancias/instb/instb_3_2_100.t…  100            0.146484    true                 49174.2
#   62 │ instancias/instb/instb_3_2_1000.…  1000           51.139      true                 4.99173e5
#   63 │ instancias/instb/instb_3_2_200.t…  200            0.615726    true                 99205.0
#   64 │ instancias/instb/instb_3_2_50.txt  50             0.03055     true                 24230.0
#   65 │ instancias/instb/instb_3_2_500.t…  500            7.2749      true                 2.49182e5
#   66 │ instancias/instb/instb_3_3_100.t…  100            0.144761    true                 49197.4
#   67 │ instancias/instb/instb_3_3_1000.…  1000           52.1078     true                 4.99173e5
#   68 │ instancias/instb/instb_3_3_200.t…  200            0.597369    true                 99224.4
#   69 │ instancias/instb/instb_3_3_50.txt  50             0.0306921   true                 24097.9
#   70 │ instancias/instb/instb_3_3_500.t…  500            7.3771      true                 2.49173e5
#   71 │ instancias/instb/instb_3_4_100.t…  100            0.144761    true                 49267.6
#   72 │ instancias/instb/instb_3_4_1000.…  1000           52.2028     true                 4.99167e5
#   73 │ instancias/instb/instb_3_4_200.t…  200            0.626653    true                 99181.4
#   74 │ instancias/instb/instb_3_4_50.txt  50             0.0304201   true                 24321.0
#   75 │ instancias/instb/instb_3_4_500.t…  500            7.02732     true                 2.49166e5
#   76 │ instancias/instb/instb_3_5_100.t…  100            0.151323    true                 49144.1
#   77 │ instancias/instb/instb_3_5_1000.…  1000           51.7259     true                 4.99194e5
#   78 │ instancias/instb/instb_3_5_200.t…  200            0.586651    true                 99119.7
#   79 │ instancias/instb/instb_3_5_50.txt  50             0.0305841   true                 24264.1
#   80 │ instancias/instb/instb_3_5_500.t…  500            6.95697     true                 2.49247e5
#   81 │ instancias/instb/instb_3_6_100.t…  100            0.141566    true                 48990.1
#   82 │ instancias/instb/instb_3_6_1000.…  1000           52.357      true                 4.99169e5
#   83 │ instancias/instb/instb_3_6_200.t…  200            0.61561     true                 99213.5
#   84 │ instancias/instb/instb_3_6_50.txt  50             0.030318    true                 24201.7
#   85 │ instancias/instb/instb_3_6_500.t…  500            7.05984     true                 2.49205e5
#   86 │ instancias/instb/instb_3_7_100.t…  100            0.140929    true                 49241.2
#   87 │ instancias/instb/instb_3_7_1000.…  1000           51.5902     true                 4.99159e5
#   88 │ instancias/instb/instb_3_7_200.t…  200            0.602127    true                 99218.5
#   89 │ instancias/instb/instb_3_7_50.txt  50             0.030566    true                 24249.7
#   90 │ instancias/instb/instb_3_7_500.t…  500            6.98951     true                 249160.0
#   91 │ instancias/instb/instb_3_8_100.t…  100            0.145402    true                 49292.6
#   92 │ instancias/instb/instb_3_8_1000.…  1000           51.1484     true                 4.99217e5
#   93 │ instancias/instb/instb_3_8_200.t…  200            0.591636    true                 99223.4
#   94 │ instancias/instb/instb_3_8_50.txt  50             0.031441    true                 24184.7
#   95 │ instancias/instb/instb_3_8_500.t…  500            7.00645     true                 2.49158e5
#   96 │ instancias/instb/instb_3_9_100.t…  100            0.146819    true                 49261.7
#   97 │ instancias/instb/instb_3_9_1000.…  1000           51.4955     true                 4.99208e5
#   98 │ instancias/instb/instb_3_9_200.t…  200            0.592424    true                 99210.8
#   99 │ instancias/instb/instb_3_9_50.txt  50             0.0306919   true                 24118.7
#  100 │ instancias/instb/instb_3_9_500.t…  500            7.03149     true                 249194.0

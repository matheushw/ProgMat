# %% [markdown]
# ## Hungaro - Instâncias A (números inteiros)

# %%
using DelimitedFiles
using Hungarian
using CSV
using DataFrames

# Criando os arrays que irão armazenar os dados de resolução de cada instância
fileName = []
agentsNumber = []
solveTime = []
isOptimalSolution = []
solution = []

# Obtendo o nome de todas as instâncias
files = readdir("instancias/insta"; join=true)
# Out:
# 105-element Vector{String}:
#  "instancias/insta/inst_1_100.txt"
#  "instancias/insta/inst_1_1000.txt"
#  "instancias/insta/inst_1_200.txt"
#  "instancias/insta/inst_1_50.txt"
#  "instancias/insta/inst_1_500.txt"
#  "instancias/insta/insta_2_10_100.txt"
#  "instancias/insta/insta_2_10_1000.txt"
#  "instancias/insta/insta_2_10_200.txt"
#  "instancias/insta/insta_2_10_50.txt"
#  "instancias/insta/insta_2_10_500.txt"
#  "instancias/insta/insta_2_1_100.txt"
#  "instancias/insta/insta_2_1_1000.txt"
#  "instancias/insta/insta_2_1_200.txt"
#  ⋮
#  "instancias/insta/insta_3_7_50.txt"
#  "instancias/insta/insta_3_7_500.txt"
#  "instancias/insta/insta_3_8_100.txt"
#  "instancias/insta/insta_3_8_1000.txt"
#  "instancias/insta/insta_3_8_200.txt"
#  "instancias/insta/insta_3_8_50.txt"
#  "instancias/insta/insta_3_8_500.txt"
#  "instancias/insta/insta_3_9_100.txt"
#  "instancias/insta/insta_3_9_1000.txt"
#  "instancias/insta/insta_3_9_200.txt"
#  "instancias/insta/insta_3_9_50.txt"
#  "instancias/insta/insta_3_9_500.txt"

# %%
# Iterando sob cada instância
for f in files
    # Lendo a matriz de custo
    c = readdlm(f, Int)

    # Checando o tamanho das linhas da matriz
    n = size(c)[1]

    start_time = time_ns()
    
    assignment, cost = hungarian(-c)
    
    end_time = time_ns()
    
    # Calculando o tempo de solução em segundos
    elapsed = (end_time - start_time)*1e-9
    
    # Adicionando nos arrays os valores referentes a instância em questão e sua solução.
    push!(fileName, f)
    push!(agentsNumber, n)
    push!(solveTime, elapsed)
    push!(solution, -cost)
end

# %%
# Criando um dataframe com os dados coletados
const dataFrame = DataFrame(
    file_name = fileName,
    agents_number = agentsNumber,
    solve_time = solveTime,
    solution = solution
)

# Escrevendo esse dataframe em um .csv para uma futura análise dos dados
CSV.write("hungarian_data_insta.csv", dataFrame)

println(dataFrame)
# Out:
# 105×4 DataFrame
#  Row │ file_name                          agents_number  solve_time   solution
#      │ Any                                Any            Any          Any
# ─────┼─────────────────────────────────────────────────────────────────────────
#    1 │ instancias/insta/inst_1_100.txt    100            0.541785     100
#    2 │ instancias/insta/inst_1_1000.txt   1000           0.155365     1000
#    3 │ instancias/insta/inst_1_200.txt    200            0.00276388   200
#    4 │ instancias/insta/inst_1_50.txt     50             0.000140041  50
#    5 │ instancias/insta/inst_1_500.txt    500            0.023353     500
#    6 │ instancias/insta/insta_2_10_100.…  100            0.00143025   4972
#    7 │ instancias/insta/insta_2_10_1000…  1000           0.0190592    50000
#    8 │ instancias/insta/insta_2_10_200.…  200            0.000977209  9996
#    9 │ instancias/insta/insta_2_10_50.t…  50             0.00012575   2464
#   10 │ instancias/insta/insta_2_10_500.…  500            0.0510599    25000
#   11 │ instancias/insta/insta_2_1_100.t…  100            0.000285792  4979
#   12 │ instancias/insta/insta_2_1_1000.…  1000           0.0201864    50000
#   13 │ instancias/insta/insta_2_1_200.t…  200            0.0009025    9995
#   14 │ instancias/insta/insta_2_1_50.txt  50             8.8166e-5    2448
#   15 │ instancias/insta/insta_2_1_500.t…  500            0.00522488   25000
#   16 │ instancias/insta/insta_2_2_100.t…  100            0.000273625  4973
#   17 │ instancias/insta/insta_2_2_1000.…  1000           0.0235596    50000
#   18 │ instancias/insta/insta_2_2_200.t…  200            0.000914167  9995
#   19 │ instancias/insta/insta_2_2_50.txt  50             7.8167e-5    2454
#   20 │ instancias/insta/insta_2_2_500.t…  500            0.00450667   25000
#   21 │ instancias/insta/insta_2_3_100.t…  100            0.000282375  4970
#   22 │ instancias/insta/insta_2_3_1000.…  1000           0.0192483    50000
#   23 │ instancias/insta/insta_2_3_200.t…  200            0.00244479   9997
#   24 │ instancias/insta/insta_2_3_50.txt  50             9.725e-5     2459
#   25 │ instancias/insta/insta_2_3_500.t…  500            0.00475771   25000
#   26 │ instancias/insta/insta_2_4_100.t…  100            0.000268792  4956
#   27 │ instancias/insta/insta_2_4_1000.…  1000           0.0215286    50000
#   28 │ instancias/insta/insta_2_4_200.t…  200            0.000840209  9994
#   29 │ instancias/insta/insta_2_4_50.txt  50             9.7041e-5    2453
#   30 │ instancias/insta/insta_2_4_500.t…  500            0.00490496   25000
#   31 │ instancias/insta/insta_2_5_100.t…  100            0.000283916  4969
#   32 │ instancias/insta/insta_2_5_1000.…  1000           0.0192404    50000
#   33 │ instancias/insta/insta_2_5_200.t…  200            0.000966708  9994
#   34 │ instancias/insta/insta_2_5_50.txt  50             8.4792e-5    2449
#   35 │ instancias/insta/insta_2_5_500.t…  500            0.00506083   25000
#   36 │ instancias/insta/insta_2_6_100.t…  100            0.000266375  4966
#   37 │ instancias/insta/insta_2_6_1000.…  1000           0.0198073    50000
#   38 │ instancias/insta/insta_2_6_200.t…  200            0.000988208  9995
#   39 │ instancias/insta/insta_2_6_50.txt  50             8.0625e-5    2449
#   40 │ instancias/insta/insta_2_6_500.t…  500            0.00524933   25000
#   41 │ instancias/insta/insta_2_7_100.t…  100            0.000314459  4970
#   42 │ instancias/insta/insta_2_7_1000.…  1000           0.0198183    50000
#   43 │ instancias/insta/insta_2_7_200.t…  200            0.00107108   9993
#   44 │ instancias/insta/insta_2_7_50.txt  50             7.5208e-5    2459
#   45 │ instancias/insta/insta_2_7_500.t…  500            0.00518496   25000
#   46 │ instancias/insta/insta_2_8_100.t…  100            0.0003155    4974
#   47 │ instancias/insta/insta_2_8_1000.…  1000           0.0199       50000
#   48 │ instancias/insta/insta_2_8_200.t…  200            0.000883541  9994
#   49 │ instancias/insta/insta_2_8_50.txt  50             0.0001065    2449
#   50 │ instancias/insta/insta_2_8_500.t…  500            0.00686433   25000
#   51 │ instancias/insta/insta_2_9_100.t…  100            0.000298292  4963
#   52 │ instancias/insta/insta_2_9_1000.…  1000           0.0195235    50000
#   53 │ instancias/insta/insta_2_9_200.t…  200            0.00101175   9999
#   54 │ instancias/insta/insta_2_9_50.txt  50             9.3041e-5    2449
#   55 │ instancias/insta/insta_2_9_500.t…  500            0.00485279   25000
#   56 │ instancias/insta/insta_3_10_100.…  100            0.000395792  49297
#   57 │ instancias/insta/insta_3_10_1000…  1000           0.0245353    499630
#   58 │ instancias/insta/insta_3_10_200.…  200            0.00107508   99310
#   59 │ instancias/insta/insta_3_10_50.t…  50             0.00014125   24261
#   60 │ instancias/insta/insta_3_10_500.…  500            0.00534621   249397
#   61 │ instancias/insta/insta_3_1_100.t…  100            0.000391959  49386
#   62 │ instancias/insta/insta_3_1_1000.…  1000           0.0227009    499662
#   63 │ instancias/insta/insta_3_1_200.t…  200            0.00109633   99269
#   64 │ instancias/insta/insta_3_1_50.txt  50             0.000186875  24242
#   65 │ instancias/insta/insta_3_1_500.t…  500            0.0059775    249430
#   66 │ instancias/insta/insta_3_2_100.t…  100            0.000433292  49259
#   67 │ instancias/insta/insta_3_2_1000.…  1000           0.0237153    499640
#   68 │ instancias/insta/insta_3_2_200.t…  200            0.00103742   99242
#   69 │ instancias/insta/insta_3_2_50.txt  50             0.000191375  24214
#   70 │ instancias/insta/insta_3_2_500.t…  500            0.00601142   249436
#   71 │ instancias/insta/insta_3_3_100.t…  100            0.000522708  49237
#   72 │ instancias/insta/insta_3_3_1000.…  1000           0.0224642    499654
#   73 │ instancias/insta/insta_3_3_200.t…  200            0.00114513   99310
#   74 │ instancias/insta/insta_3_3_50.txt  50             0.0001365    24289
#   75 │ instancias/insta/insta_3_3_500.t…  500            0.00478829   249466
#   76 │ instancias/insta/insta_3_4_100.t…  100            0.000448333  49297
#   77 │ instancias/insta/insta_3_4_1000.…  1000           0.0228015    499668
#   78 │ instancias/insta/insta_3_4_200.t…  200            0.00129513   99334
#   79 │ instancias/insta/insta_3_4_50.txt  50             0.000193583  24239
#   80 │ instancias/insta/insta_3_4_500.t…  500            0.00524383   249474
#   81 │ instancias/insta/insta_3_5_100.t…  100            0.000385375  49268
#   82 │ instancias/insta/insta_3_5_1000.…  1000           0.0223576    499657
#   83 │ instancias/insta/insta_3_5_200.t…  200            0.00115875   99278
#   84 │ instancias/insta/insta_3_5_50.txt  50             0.000130125  24021
#   85 │ instancias/insta/insta_3_5_500.t…  500            0.00509617   249456
#   86 │ instancias/insta/insta_3_6_100.t…  100            0.000511375  49220
#   87 │ instancias/insta/insta_3_6_1000.…  1000           0.0232072    499635
#   88 │ instancias/insta/insta_3_6_200.t…  200            0.00114738   99262
#   89 │ instancias/insta/insta_3_6_50.txt  50             0.000104625  24296
#   90 │ instancias/insta/insta_3_6_500.t…  500            0.00725817   249431
#   91 │ instancias/insta/insta_3_7_100.t…  100            0.000440333  49277
#   92 │ instancias/insta/insta_3_7_1000.…  1000           0.0241188    499634
#   93 │ instancias/insta/insta_3_7_200.t…  200            0.00109533   99318
#   94 │ instancias/insta/insta_3_7_50.txt  50             0.000171167  24187
#   95 │ instancias/insta/insta_3_7_500.t…  500            0.00551158   249439
#   96 │ instancias/insta/insta_3_8_100.t…  100            0.000390917  49365
#   97 │ instancias/insta/insta_3_8_1000.…  1000           0.0244488    499628
#   98 │ instancias/insta/insta_3_8_200.t…  200            0.00106912   99275
#   99 │ instancias/insta/insta_3_8_50.txt  50             0.000110208  24190
#  100 │ instancias/insta/insta_3_8_500.t…  500            0.00510771   249498
#  101 │ instancias/insta/insta_3_9_100.t…  100            0.000306667  49218
#  102 │ instancias/insta/insta_3_9_1000.…  1000           0.021638     499663
#  103 │ instancias/insta/insta_3_9_200.t…  200            0.00112938   99270
#  104 │ instancias/insta/insta_3_9_50.txt  50             0.000144667  24248
#  105 │ instancias/insta/insta_3_9_500.t…  500            0.00600904   249468
